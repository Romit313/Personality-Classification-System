# %%
import pandas as pd

df = pd.read_csv('data-final.csv', delimiter="\t")
df
# Out:
#        EXT1  EXT2  EXT3  ...  country  lat_appx_lots_of_err  long_appx_lots_of_err
# 0         4     1     5  ...       GB               51.5448                 0.1991
# 1         3     5     3  ...       MY                3.1698                101.706
# 2         2     3     4  ...       GB               54.9119                -1.3833
# 3         2     2     2  ...       GB                 51.75                  -1.25
# 4         3     3     3  ...       KE                   1.0                   38.0
# ...     ...   ...   ...  ...      ...                   ...                    ...
# 10214     2     4     4  ...       GB                  51.5                  -0.13
# 10215     1     3     2  ...       US                  38.0                  -97.0
# 10216     3     4     4  ...     NONE                  NONE                   NONE
# 10217     1     1     4  ...       US               32.8019               -96.7883
# 10218     3     3     5  ...      NaN                   NaN                    NaN
#
# [10219 rows x 110 columns]

# %%
columns = df.columns
for column in columns:
    print(column)
# Out:
# EXT1
# EXT2
# EXT3
# EXT4
# EXT5
# EXT6
# EXT7
# EXT8
# EXT9
# EXT10
# EST1
# EST2
# EST3
# EST4
# EST5
# EST6
# EST7
# EST8
# EST9
# EST10
# AGR1
# AGR2
# AGR3
# AGR4
# AGR5
# AGR6
# AGR7
# AGR8
# AGR9
# AGR10
# CSN1
# CSN2
# CSN3
# CSN4
# CSN5
# CSN6
# CSN7
# CSN8
# CSN9
# CSN10
# OPN1
# OPN2
# OPN3
# OPN4
# OPN5
# OPN6
# OPN7
# OPN8
# OPN9
# OPN10
# EXT1_E
# EXT2_E
# EXT3_E
# EXT4_E
# EXT5_E
# EXT6_E
# EXT7_E
# EXT8_E
# EXT9_E
# EXT10_E
# EST1_E
# EST2_E
# EST3_E
# EST4_E
# EST5_E
# EST6_E
# EST7_E
# EST8_E
# EST9_E
# EST10_E
# AGR1_E
# AGR2_E
# AGR3_E
# AGR4_E
# AGR5_E
# AGR6_E
# AGR7_E
# AGR8_E
# AGR9_E
# AGR10_E
# CSN1_E
# CSN2_E
# CSN3_E
# CSN4_E
# CSN5_E
# CSN6_E
# CSN7_E
# CSN8_E
# CSN9_E
# CSN10_E
# OPN1_E
# OPN2_E
# OPN3_E
# OPN4_E
# OPN5_E
# OPN6_E
# OPN7_E
# OPN8_E
# OPN9_E
# OPN10_E
# dateload
# screenw
# screenh
# introelapse
# testelapse
# endelapse
# IPC
# country
# lat_appx_lots_of_err
# long_appx_lots_of_err

# %%
import numpy as np
X = df[df.columns[0:50]]
pd.set_option('display.max_columns', None)
X
# Out:
#        EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  EST1  \
# 0         4     1     5     2     5     1     5     2     4      1     1
# 1         3     5     3     4     3     3     2     5     1      5     2
# 2         2     3     4     4     3     2     1     3     2      5     4
# 3         2     2     2     3     4     2     2     4     1      4     3
# 4         3     3     3     3     5     3     3     5     3      4     1
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...    ...   ...
# 10214     2     4     4     4     2     4     2     2     2      2     3
# 10215     1     3     2     5     3     3     1     5     1      5     4
# 10216     3     4     4     4     4     4     2     5     2      5     4
# 10217     1     1     4     2     4     1     2     3     1      4     4
# 10218     3     3     5     3     5     5     5     4     3      5     4
#
#        EST2  EST3  EST4  EST5  EST6  EST7  EST8  EST9  EST10  AGR1  AGR2  \
# 0         4     4     2     2     2     2     2     3      2     2     5
# 1         3     4     1     3     1     2     1     3      1     1     4
# 2         4     4     2     2     2     2     2     1      3     1     4
# 3         3     3     2     3     2     2     2     4      3     2     4
# 4         5     5     3     1     1     1     1     3      2     1     5
# ...     ...   ...   ...   ...   ...   ...   ...   ...    ...   ...   ...
# 10214     4     5     3     3     3     1     1     2      2     4     4
# 10215     3     5     2     2     3     3     2     3      4     4     3
# 10216     5     4     2     5     2     5     2     4      4     1     5
# 10217     4     4     3     2     2     5     5     4      3     4     3
# 10218     5     5     1     1     1     1     1     1      1     5     5
#
#        AGR3  AGR4  AGR5  AGR6  AGR7  AGR8  AGR9  AGR10  CSN1  CSN2  CSN3  \
# 0         2     4     2     3     2     4     3      4     3     4     3
# 1         1     5     1     5     3     4     5      3     3     2     5
# 2         1     4     2     4     1     4     4      3     4     2     2
# 3         3     4     2     4     2     4     3      4     2     4     4
# 4         1     5     1     3     1     5     5      3     5     1     5
# ...     ...   ...   ...   ...   ...   ...   ...    ...   ...   ...   ...
# 10214     2     4     1     4     2     4     4      5     4     3     3
# 10215     4     3     4     2     3     3     3      4     3     3     5
# 10216     2     5     1     4     1     4     5      4     4     5     5
# 10217     5     4     4     4     2     4     3      5     4     4     4
# 10218     1     5     5     5     1     5     5      5     4     5     5
#
#        CSN4  CSN5  CSN6  CSN7  CSN8  CSN9  CSN10  OPN1  OPN2  OPN3  OPN4  \
# 0         2     2     4     4     2     4      4     5     1     4     1
# 1         3     3     1     3     3     5      3     1     2     4     2
# 2         2     3     3     4     2     4      2     5     1     2     1
# 3         4     1     2     2     3     1      4     4     2     5     2
# 4         1     3     1     5     1     5      5     5     1     5     1
# ...     ...   ...   ...   ...   ...   ...    ...   ...   ...   ...   ...
# 10214     3     1     2     4     4     3      3     4     2     3     2
# 10215     3     3     3     4     2     3      3     5     1     5     3
# 10216     2     2     5     5     4     4      4     5     2     4     1
# 10217     2     1     2     3     2     2      2     2     2     5     4
# 10218     1     5     1     5     1     3      4     3     3     3     1
#
#        OPN5  OPN6  OPN7  OPN8  OPN9  OPN10
# 0         4     1     5     3     4      5
# 1         3     1     4     2     5      3
# 2         4     2     5     3     4      4
# 3         3     1     4     4     3      3
# 4         5     1     5     3     5      5
# ...     ...   ...   ...   ...   ...    ...
# 10214     4     3     4     4     0      4
# 10215     4     1     5     5     5      5
# 10216     4     2     5     1     4      4
# 10217     4     1     5     2     5      4
# 10218     3     5     5     5     4      5
#
# [10219 rows x 50 columns]

# %%
X = X.fillna(0)
from sklearn.cluster import MiniBatchKMeans
kmeans = MiniBatchKMeans(n_clusters=10, random_state=0, batch_size=100, max_iter=100).fit(X)
len(kmeans.cluster_centers_)
# Out:
# 10

# %%
one = kmeans.cluster_centers_[0]
two = kmeans.cluster_centers_[1]
three =kmeans.cluster_centers_[2]
four = kmeans.cluster_centers_[3]
five =kmeans.cluster_centers_[4]
six = kmeans.cluster_centers_[5]
seven = kmeans.cluster_centers_[6]
eight = kmeans.cluster_centers_[7]
nine= kmeans.cluster_centers_[8]
ten = kmeans.cluster_centers_[9]
one
# Out:
# array([3.57313643, 1.73980309, 3.93178622, 2.35302391, 4.13431786,
#        1.88045007, 3.83544304, 2.63220816, 3.91209564, 2.92264416,
#        3.94233474, 2.89451477, 4.31926864, 2.37974684, 3.51195499,
#        3.65400844, 4.0323488 , 3.74331927, 3.86638537, 3.33122363,
#        2.10407876, 4.31715893, 2.91561181, 4.15260197, 1.98171589,
#        3.95780591, 1.83614627, 3.9092827 , 4.15541491, 3.84810127,
#        2.61462729, 3.88818565, 3.66033755, 3.6350211 , 1.88537271,
#        3.87201125, 3.17580872, 3.05696203, 2.64767932, 3.28973277,
#        3.68495077, 2.23980309, 4.197609  , 2.03586498, 3.85864979,
#        1.82841069, 3.86708861, 3.39170183, 4.04500703, 4.07243319])

# %%
one_scores = {}

one_scores['extroversion_score'] =  one[0] - one[1] + one[2] - one[3] + one[4] - one[5] + one[6] - one[7] + one[8] - one[9]
one_scores['neuroticism_score'] =  one[0] - one[1] + one[2] - one[3] + one[4] + one[5] + one[6] + one[7] + one[8] + one[9]
one_scores['agreeableness_score'] =  -one[0] + one[1] - one[2] + one[3] - one[4] - one[5] + one[6] - one[7] + one[8] + one[9]
one_scores['conscientiousness_score'] =  one[0] - one[1] + one[2] - one[3] + one[4] - one[5] + one[6] - one[7] + one[8] + one[9]
one_scores['openness_score'] =  one[0] - one[1] + one[2] - one[3] + one[4] - one[5] + one[6] + one[7] + one[8] + one[9]
one_scores
# Out:
# {'agreeableness_score': -1.3888888888888897,
#  'conscientiousness_score': 13.70393811533052,
#  'extroversion_score': 7.858649789029535,
#  'neuroticism_score': 22.729254571026722,
#  'openness_score': 18.968354430379748}

# %%
all_types = {'one':one, 'two': two, 'three' :three, 'four':four, 'five':five, 'six': six, 'seven': seven, 'eight': eight,
             'nine': nine, 'ten': ten}

all_types_scores ={}

for name, personality_type in all_types.items():
    personality_trait = {}

    personality_trait['extroversion_score'] =  personality_type[0] - personality_type[1] +personality_type[2] - personality_type[3] + personality_type[4] - personality_type[5] +personality_type[6] - personality_type[7] + personality_type[8] -personality_type[9]
    personality_trait['neuroticism_score'] =  personality_type[0] - personality_type[1] + personality_type[2] -personality_type[3] + personality_type[4] + personality_type[5] + personality_type[6] + personality_type[7] + personality_type[8] + personality_type[9]
    personality_trait['agreeableness_score'] =  -personality_type[0] +personality_type[1] - personality_type[2] + personality_type[3] - personality_type[4] - personality_type[5] + personality_type[6] - personality_type[7] + personality_type[8] + personality_type[9]
    personality_trait['conscientiousness_score'] = personality_type[0] - personality_type[1] + personality_type[2] -personality_type[3] +personality_type[4] - personality_type[5] +personality_type[6] -personality_type[7] + personality_type[8] + personality_type[9]
    personality_trait['openness_score'] =  personality_type[0] -personality_type[1] + personality_type[2] - personality_type[3] + personality_type[4] - personality_type[5] +personality_type[6] + personality_type[7] + personality_type[8] + personality_type[9]
    
    all_types_scores[name] = personality_trait
all_types_scores
# Out:
# {'eight': {'agreeableness_score': 3.215371621621625,
#   'conscientiousness_score': -2.8623310810810816,
#   'extroversion_score': -12.205236486486488,
#   'neuroticism_score': 12.907939189189193,
#   'openness_score': 5.706925675675677},
#  'five': {'agreeableness_score': 0.6308479532163735,
#   'conscientiousness_score': 1.92616959064327,
#   'extroversion_score': -6.218567251461988,
#   'neuroticism_score': 16.231725146198823,
#   'openness_score': 9.817982456140346},
#  'four': {'agreeableness_score': 0.1125087351502514,
#   'conscientiousness_score': 9.037735849056602,
#   'extroversion_score': 1.993710691823893,
#   'neuroticism_score': 20.044025157232703,
#   'openness_score': 15.170510132774282},
#  'nine': {'agreeableness_score': -2.200859950859957,
#   'conscientiousness_score': 14.949017199017186,
#   'extroversion_score': 10.156633906633898,
#   'neuroticism_score': 23.01044226044224,
#   'openness_score': 19.88882063882062},
#  'one': {'agreeableness_score': -1.3888888888888897,
#   'conscientiousness_score': 13.70393811533052,
#   'extroversion_score': 7.858649789029535,
#   'neuroticism_score': 22.729254571026722,
#   'openness_score': 18.968354430379748},
#  'seven': {'agreeableness_score': -1.1764705882352948,
#   'conscientiousness_score': 8.627941176470591,
#   'extroversion_score': 1.510294117647057,
#   'neuroticism_score': 20.11470588235295,
#   'openness_score': 15.975000000000003},
#  'six': {'agreeableness_score': 1.0799180327868867,
#   'conscientiousness_score': 2.24385245901639,
#   'extroversion_score': -6.305327868852462,
#   'neuroticism_score': 17.047131147540977,
#   'openness_score': 9.874999999999996},
#  'ten': {'agreeableness_score': -1.0601092896174933,
#   'conscientiousness_score': 9.737704918032787,
#   'extroversion_score': 3.7049180327868854,
#   'neuroticism_score': 20.202185792349724,
#   'openness_score': 16.290983606557376},
#  'three': {'agreeableness_score': 0.9089848308051316,
#   'conscientiousness_score': 5.140023337222873,
#   'extroversion_score': -1.8144690781796933,
#   'neuroticism_score': 16.388564760793468,
#   'openness_score': 11.487747957993003},
#  'two': {'agreeableness_score': 2.3527679623085938,
#   'conscientiousness_score': 0.7355712603062408,
#   'extroversion_score': -8.247938751472322,
#   'neuroticism_score': 14.703769140164905,
#   'openness_score': 8.967608951707891}}

# %%
all_extroversion = []
all_neuroticism =[]
all_agreeableness =[]
all_conscientiousness =[]
all_openness =[]

for personality_type, personality_trait in all_types_scores.items():
    all_extroversion.append(personality_trait['extroversion_score'])
    all_neuroticism.append(personality_trait['neuroticism_score'])
    all_agreeableness.append(personality_trait['agreeableness_score'])
    all_conscientiousness.append(personality_trait['conscientiousness_score'])
    all_openness.append(personality_trait['openness_score'])
all_extroversion_normalized = (all_extroversion-min(all_extroversion))/(max(all_extroversion)-min(all_extroversion))
all_neuroticism_normalized = (all_neuroticism-min(all_neuroticism))/(max(all_neuroticism)-min(all_neuroticism))
all_agreeableness_normalized = (all_agreeableness-min(all_agreeableness))/(max(all_agreeableness)-min(all_agreeableness))
all_conscientiousness_normalized = (all_conscientiousness-min(all_conscientiousness))/(max(all_conscientiousness)-min(all_conscientiousness))
all_openness_normalized = (all_openness-min(all_openness))/(max(all_openness)-min(all_openness))
all_extroversion_normalized
# Out:
# array([0.8972365 , 0.17696631, 0.4646645 , 0.63496241, 0.26771773,
#        0.26383789, 0.61334452, 0.        , 1.        , 0.71148586])

# %%
counter = 0

normalized_all_types_scores ={}

for personality_type, personality_trait in all_types_scores.items():
    normalized_personality_trait ={}
    normalized_personality_trait['extroversion_score'] = all_extroversion_normalized[counter]
    normalized_personality_trait['neuroticism_score'] = all_neuroticism_normalized[counter]
    normalized_personality_trait['agreeableness_score'] = all_agreeableness_normalized[counter]
    normalized_personality_trait['conscientiousness_score'] = all_conscientiousness_normalized[counter]
    normalized_personality_trait['openness_score'] = all_openness_normalized[counter]
    
    normalized_all_types_scores[personality_type] = normalized_personality_trait
    
    counter+=1
normalized_all_types_scores
# Out:
# {'eight': {'agreeableness_score': 1.0,
#   'conscientiousness_score': 0.0,
#   'extroversion_score': 0.0,
#   'neuroticism_score': 0.0,
#   'openness_score': 0.0},
#  'five': {'agreeableness_score': 0.5228188392947373,
#   'conscientiousness_score': 0.2688454908871128,
#   'extroversion_score': 0.26771773245167785,
#   'neuroticism_score': 0.3290061812965497,
#   'openness_score': 0.28988063944545045},
#  'four': {'agreeableness_score': 0.42711775799317986,
#   'conscientiousness_score': 0.6681171320104032,
#   'extroversion_score': 0.6349624127451645,
#   'neuroticism_score': 0.7063681067664747,
#   'openness_score': 0.6673004194215231},
#  'nine': {'agreeableness_score': 0.0,
#   'conscientiousness_score': 1.0,
#   'extroversion_score': 1.0,
#   'neuroticism_score': 1.0,
#   'openness_score': 1.0},
#  'one': {'agreeableness_score': 0.14991439178791285,
#   'conscientiousness_score': 0.9300963035416093,
#   'extroversion_score': 0.8972364977881575,
#   'neuroticism_score': 0.9721665326471768,
#   'openness_score': 0.9350956828524732},
#  'seven': {'agreeableness_score': 0.1891332283186172,
#   'conscientiousness_score': 0.6451096276855398,
#   'extroversion_score': 0.6133445173867531,
#   'neuroticism_score': 0.713364464463348,
#   'openness_score': 0.7240269619122397},
#  'six': {'agreeableness_score': 0.6057307446593672,
#   'conscientiousness_score': 0.28668147182338405,
#   'extroversion_score': 0.2638378862731057,
#   'neuroticism_score': 0.4097194456817311,
#   'openness_score': 0.2939010855147398},
#  'ten': {'agreeableness_score': 0.21061703990617966,
#   'conscientiousness_score': 0.707416182142296,
#   'extroversion_score': 0.7114858569329747,
#   'neuroticism_score': 0.7220236956835492,
#   'openness_score': 0.746307736616786},
#  'three': {'agreeableness_score': 0.574171310817908,
#   'conscientiousness_score': 0.4492840346761107,
#   'extroversion_score': 0.4646645037126907,
#   'neuroticism_score': 0.3445310085090191,
#   'openness_score': 0.40761987712785774},
#  'two': {'agreeableness_score': 0.840737300876187,
#   'conscientiousness_score': 0.20200056081141723,
#   'extroversion_score': 0.1769663120948785,
#   'neuroticism_score': 0.1777608913661997,
#   'openness_score': 0.22991872979639763}}

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
plt.ylim(0, 1)
plt.bar(list(normalized_all_types_scores['one'].keys()), normalized_all_types_scores['one'].values(), color='b')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.ylim(0, 1)
plt.bar(list(normalized_all_types_scores['two'].keys()), normalized_all_types_scores['two'].values(), color='b')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.ylim(0, 1)
plt.bar(list(normalized_all_types_scores['three'].keys()), normalized_all_types_scores['three'].values(), color='b')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.ylim(0, 1)
plt.bar(list(normalized_all_types_scores['four'].keys()), normalized_all_types_scores['four'].values(), color='b')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.ylim(0, 1)
plt.bar(list(normalized_all_types_scores['five'].keys()), normalized_all_types_scores['five'].values(), color='b')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.ylim(0, 1)
plt.bar(list(normalized_all_types_scores['six'].keys()), normalized_all_types_scores['six'].values(), color='b')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.ylim(0, 1)
plt.bar(list(normalized_all_types_scores['seven'].keys()), normalized_all_types_scores['seven'].values(), color='b')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.ylim(0, 1)
plt.bar(list(normalized_all_types_scores['eight'].keys()), normalized_all_types_scores['eight'].values(), color='b')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.ylim(0, 1)
plt.bar(list(normalized_all_types_scores['nine'].keys()), normalized_all_types_scores['nine'].values(), color='b')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.ylim(0, 1)
plt.bar(list(normalized_all_types_scores['ten'].keys()), normalized_all_types_scores['ten'].values(), color='b')
plt.show()
